# %% [markdown]
# ##**Imports**

# %%
import os
# import pandas as pd
import torch
# import sklearn
# from IPython.core.display import display, HTML
# import glob
# import numpy as np
from torch.utils.data import Dataset, DataLoader
# import re
# import torch.nn.functional as F

# %% [markdown]
# ##**Installing Transformers**

# %% [markdown]
# The `transformers` library is a popular open-source library developed by Hugging Face. It provides pre-trained models and various tools to work with state-of-the-art natural language processing (NLP) models, including those based on transformer architectures.
#
# When you install `transformers` using the command `!pip -q install transformers`, you're adding this library to your Python environment. This enables you to easily access pre-trained transformer models, such as BERT, GPT, and many others, without having to train them from scratch. This is incredibly useful for tasks like text classification, language modeling, translation, and more.
#
# The library also offers helpful utilities for tokenization, model loading, and fine-tuning, making it a go-to choice for many researchers and practitioners in the field of NLP and AI.

# %%
# !pip -q install transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 46.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 105.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.1 MB/s eta 0:00:00

# %% [markdown]
# `sentencepiece` is a library for tokenizing natural language text into subword units. It's often used in conjunction with transformer-based models like BERT. When you install `sentencepiece` using the command `!pip install sentencepiece`, you're adding support for this tokenization method to your environment.
#
# In the context of transformer models, tokenization is a crucial step. It involves breaking down a sequence of text into smaller units, usually words or subwords, to be processed by the model. `sentencepiece` is one of the tokenizers that allows for a flexible and efficient way of handling this task.
#
# By combining `transformers` and `sentencepiece`, you're setting up your environment to work seamlessly with transformer-based NLP models that use subword tokenization.

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.9 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from apikey_h import apikey_h

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN']= apikey_h

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. `from transformers import MarianMTModel, MarianTokenizer`: This line imports the `MarianMTModel` and `MarianTokenizer` classes from the `transformers` library. These classes are specific to MarianMT, which is a multilingual transformer model for machine translation.
#
# 2. `model_name = 'Helsinki-NLP/opus-mt-ml-en'`: Here, you're defining the model name or identifier. In this case, it's specifying the 'opus-mt-ml-en' model provided by Helsinki-NLP. This model is capable of translating between Malayalam and English.
#
# 3. `model = MarianMTModel.from_pretrained(model_name)`: This line initializes a `MarianMTModel` using the pre-trained weights specified by the `model_name`. It loads the pre-trained parameters of the model so that you can use it for translation without training it from scratch.
#
# 4. `tokenizer = MarianTokenizer.from_pretrained(model_name)`: Similarly, this line initializes a `MarianTokenizer` using the pre-trained tokenizer associated with the specified `model_name`. The tokenizer is essential for processing input text into a format that the model can understand.
#
# Now you have a pre-trained MarianMT model and its corresponding tokenizer ready to use for machine translation tasks.
#
#
# ```python
# model = MarianMTModel.from_pretrained(model_name)
# tokenizer = MarianTokenizer.from_pretrained(model_name)
# ```
#
# automatically downloads the pre-trained weights (model parameters) and associated tokenizer files for the specified `model_name` if they are not already present in your local environment. The downloaded files are typically stored in a cache directory so that they don't need to be downloaded again if you use the same model in the future.
#
# Now that you've executed these lines, you have a pre-trained MarianMT model (`model`) and its corresponding tokenizer (`tokenizer`) ready to use for translation tasks.

# %%
from transformers import MarianMTModel, MarianTokenizer
model_name = 'Helsinki-NLP/opus-mt-ml-en'
model = MarianMTModel.from_pretrained(model_name)
tokenizer = MarianTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/source.spm:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading (…)olve/main/target.spm:   0%|          | 0.00/818k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/2.72M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
import json

# File path to your JSONL file
file_path = '/content/drive/MyDrive/Colab Notebooks/Marian/dataset_everything.jsonl'

malayalam_sentences = []
english_sentences = []

with open(file_path, 'r') as file:
    for line in file:
        try:
            # Parse each line as a JSON object
            message = json.loads(line)

            # Extract Malayalam and English sentences
            if "messages" in message:
                for msg in message["messages"]:
                    if "role" in msg and "content" in msg:
                        if msg["role"] == "user":
                            malayalam_sentences.append(msg["content"])
                        elif msg["role"] == "assistant":
                            english_sentences.append(msg["content"])

        except json.JSONDecodeError as e:
            print(f"Error decoding JSON: {e}")


# Tokenize sentences
malayalam_tokenized = [tokenizer.encode(sentence, return_tensors="pt")[0] for sentence in malayalam_sentences]
english_tokenized = [tokenizer.encode(sentence, return_tensors="pt")[0] for sentence in english_sentences]


# Truncate sequences to a specified max length (e.g., 512)
max_length = 512
malayalam_tokenized = [sequence[:max_length] for sequence in malayalam_tokenized]
english_tokenized = [sequence[:max_length] for sequence in english_tokenized]

# %%
import torch
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset, DataLoader

class TranslationDataset(Dataset):
    def __init__(self, malayalam_tokenized, english_tokenized):
        self.malayalam_tokenized = malayalam_tokenized
        self.english_tokenized = english_tokenized

    def __len__(self):
        return len(self.malayalam_tokenized)

    def __getitem__(self, idx):
        return {
            "input_ids": self.malayalam_tokenized[idx],
            "labels": self.english_tokenized[idx],
        }

def collate_fn(batch):
    input_ids = pad_sequence([item["input_ids"] for item in batch], batch_first=True)
    labels = pad_sequence([item["labels"] for item in batch], batch_first=True)

    return {"input_ids": input_ids, "labels": labels}

# Create datasets and dataloaders
translation_dataset = TranslationDataset(malayalam_tokenized, english_tokenized)
batch_size = 8  # Adjust as needed
translation_loader = DataLoader(translation_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

# %%
import torch
from transformers import AdamW, get_linear_schedule_with_warmup

# Move model to device (GPU if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define optimizer and scheduler
optimizer = AdamW(model.parameters(), lr=1e-4 )
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=len(translation_loader))

# Training loop
num_epochs = 3  # Adjust as needed

for epoch in range(num_epochs):
    print ('epoch:', epoch)
    model.train()


    for batch in translation_loader:
        inputs = batch["input_ids"].to(device)
        labels = batch["labels"].to(device)

        optimizer.zero_grad()

        # Forward pass
        outputs = model(input_ids=inputs, labels=labels)
        loss = outputs.loss
        print (loss)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        scheduler.step()

# Save the fine-tuned model
model.save_pretrained('/content/drive/MyDrive/Colab Notebooks/OCR_Sale_Deed')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# epoch: 0
# tensor(3.3999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7605, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5130, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5635, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9377, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9266, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1473, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1606, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8746, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4518, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2898, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6494, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0572, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8450, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3754, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3642, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4292, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1342, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1623, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3785, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7946, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5044, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5019, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7848, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4453, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3512, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2945, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2528, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6471, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5557, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8431, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2887, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4903, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9534, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8863, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9668, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1797, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8247, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8852, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3590, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8098, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6085, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3296, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6664, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9391, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0862, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3156, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7038, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8815, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4155, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0519, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8263, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8730, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2347, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5478, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1850, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8266, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0240, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2355, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4827, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0417, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0772, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3333, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8212, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4505, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8362, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2224, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6692, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7819, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7677, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8452, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2175, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7201, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3531, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9549, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1818, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4424, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5624, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0809, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5381, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9556, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6339, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8800, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7918, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4857, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.6972, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3913, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4620, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1167, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8970, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0520, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3641, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5416, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4698, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5456, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6349, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7662, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8434, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4020, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0413, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6380, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1772, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9806, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2874, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2077, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9670, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5226, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.3393, device='cuda:0', grad_fn=<NllLossBackward0>)
# epoch: 1
# tensor(4.4921, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7214, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5316, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8878, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3228, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1239, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7657, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3876, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0991, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8490, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3179, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0202, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0742, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4866, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7218, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6873, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4666, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3324, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6047, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9013, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5843, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7566, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4388, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8475, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5972, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5293, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2448, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4103, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4065, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3155, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0695, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7475, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9250, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.4774, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2853, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3364, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9783, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9999, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5126, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5651, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6486, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7552, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5070, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9673, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5373, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8487, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3570, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5500, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2593, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2826, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0646, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8639, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3079, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7855, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3311, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7395, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0098, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4327, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1084, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5253, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2212, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6970, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4727, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6907, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4134, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1693, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4513, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7511, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2445, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7880, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9874, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9951, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8793, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4735, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4052, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4669, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4464, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4656, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9684, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5339, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2569, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4472, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8192, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4056, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6332, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8018, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3340, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8308, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7791, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5990, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5563, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0762, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7454, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9867, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6191, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2031, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0539, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4844, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4118, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9369, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4671, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3731, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1156, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4939, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7122, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7632, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6120, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9179, device='cuda:0', grad_fn=<NllLossBackward0>)
# epoch: 2
# tensor(3.7765, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3949, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9545, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2268, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1353, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0505, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6563, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1491, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4051, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9323, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4383, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6495, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4355, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5649, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6291, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2224, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0356, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8617, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9625, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7792, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2823, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7002, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6384, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9609, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3036, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9997, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7892, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7046, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7448, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6057, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1095, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2176, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6451, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7574, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7325, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5717, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6861, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2833, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9582, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7068, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9361, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8265, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.8884, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.2190, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0702, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0667, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4154, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1367, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3775, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6967, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6368, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7305, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1440, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7003, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4090, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9702, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6823, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6955, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.2856, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9209, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4415, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0694, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4210, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8034, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0720, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2837, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0645, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0170, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9889, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9757, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5387, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.7422, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2682, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.5996, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6586, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0982, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4629, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6104, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.9934, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0101, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7311, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5260, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7287, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5233, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5873, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8553, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1485, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9217, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1536, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.7616, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1691, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4530, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2247, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5345, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8616, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5488, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.0660, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9542, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5807, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.9056, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.6399, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.4951, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8072, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.0739, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2478, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.4169, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.6270, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.3832, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.1063, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1506, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.2455, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.8709, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.5206, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(4.1025, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(2.5962, device='cuda:0', grad_fn=<NllLossBackward0>)
# tensor(3.3493, device='cuda:0', grad_fn=<NllLossBackward0>)

# %%
model.save_pretrained('/content/drive/MyDrive/Colab Notebooks/Marian/model_finetuned')

# %%
# Malayalam sentence
malayalam_sentence = '''ഇന്ന് നല്ല കാലാവസ്ഥ ആണ്  '''

tokenized_input = tokenizer.encode(malayalam_sentence, return_tensors="pt")

tokenized_input = tokenized_input.to(device)

model.eval()  # Set the model to evaluation mode
with torch.no_grad():
    # Generate translations
    generated = model.generate(tokenized_input)

generated_translations = tokenizer.decode(generated[0], skip_special_tokens=True)
print("Generated Translations:", generated_translations)
# Out:
# Generated Translations:
